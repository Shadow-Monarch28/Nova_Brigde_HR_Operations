# %%
# !pip install faker pandas numpy tqdm pymysql

# %%
# %run generate_novabridge_data.py
# Out:
# ...
#   NovaBridge Solutions — Dirty Dataset Generator v2
# ...
# [1/4] interaction_file.csv  (1,000,000 rows) ...
#    ... 200,000 rows
#    ... 400,000 rows
#    ... 600,000 rows
#    ... 800,000 rows
#    ✓ 1,000,000 rows, 21 cols
#    → Saved interaction_file.csv
#
# [2/4] performance_file.csv ...
#    ✓ 861 rows, 14 cols
#    → Saved performance_file.csv
#
# [3/4] survey_report.csv  (205,000 rows) ...
#    ... 50,000 rows
#    ... 100,000 rows
#    ... 150,000 rows
#    ... 200,000 rows
#    ✓ 209,510 rows, 13 cols
#    → Saved survey_report.csv
#
# [4/4] schedule_adherence_file.csv ...
#    ✓ 3,472 rows, 9 cols
#    → Saved schedule_adherence_file.csv
#
# ...
#   ✅ All 4 files generated!
#
# 📊 QA SUMMARY
#   interaction_file          rows=1,000,000  null%=6.2%
#   performance_file          rows=     861  null%=4.5%
#   survey_report             rows= 209,510  null%=6.0%
#   schedule_adherence        rows=   3,472  null%=4.4%

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import urllib.parse

# -----------------------------------
# MySQL Connection Details
# -----------------------------------
username = "Abishek"
password = "@b!$#3k@2003"
host = "127.0.0.1"
port = "3306"
database_name = "nova_bridge"

# Encode password safely
encoded_password = urllib.parse.quote_plus(password)

# -----------------------------------
# Connect WITHOUT database first
# -----------------------------------
engine = create_engine(
    f"mysql+pymysql://{username}:{encoded_password}@{host}:{port}"
)

# Create database if not exists
with engine.connect() as conn:
    conn.execute(text(f"CREATE DATABASE IF NOT EXISTS {database_name}"))
    conn.commit()
    print(f"Database '{database_name}' is ready.")

# -----------------------------------
# Reconnect WITH database
# -----------------------------------
engine = create_engine(
    f"mysql+pymysql://{username}:{encoded_password}@{host}:{port}/{database_name}"
)

# -----------------------------------
# Files and Table Names
# -----------------------------------
files = {
    "performance_file.csv": "performance",
    "schedule_adherence_file.csv": "schedule_adherence",
    "survey_report.csv": "survey_report",
    "interaction_file.csv": "interaction"
}

# -----------------------------------
# Upload Each CSV File
# -----------------------------------
for file_name, table_name in files.items():
    
    # Read CSV
    df = pd.read_csv(file_name)
    
    # Clean column names
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
    )
    
    # Upload to MySQL
    df.to_sql(
        name=table_name,
        con=engine,
        if_exists="replace",
        index=False
    )
    
    print(f"{file_name} uploaded successfully --> {table_name}")

print("All CSV files uploaded successfully.")
# Out:
# Database 'nova_bridge' is ready.
# performance_file.csv uploaded successfully --> performance
# schedule_adherence_file.csv uploaded successfully --> schedule_adherence
# survey_report.csv uploaded successfully --> survey_report
# interaction_file.csv uploaded successfully --> interaction
# All CSV files uploaded successfully.

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import urllib.parse

# -----------------------------------
# MySQL Connection Details
# -----------------------------------
username = "Abishek"
password = "@b!$#3k@2003"
host = "127.0.0.1"
port = "3306"
database_name = "nova_bridge"

# Encode password safely
encoded_password = urllib.parse.quote_plus(password)

# -----------------------------------
# Connect WITHOUT database first
# -----------------------------------
engine = create_engine(
    f"mysql+pymysql://{username}:{encoded_password}@{host}:{port}"
)

# Create database if not exists
with engine.connect() as conn:
    conn.execute(text(f"CREATE DATABASE IF NOT EXISTS {database_name}"))
    conn.commit()
    print(f"Database '{database_name}' is ready.")

# -----------------------------------
# Reconnect WITH database
# -----------------------------------
engine = create_engine(
    f"mysql+pymysql://{username}:{encoded_password}@{host}:{port}/{database_name}"
)

# -----------------------------------
# Files and Table Names
# -----------------------------------
files = {
    "interaction_file.csv": "interaction"
}

# -----------------------------------
# Upload Each CSV File
# -----------------------------------
for file_name, table_name in files.items():
    
    # Read CSV
    df = pd.read_csv(file_name)
    
    # Clean column names
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
    )
    
    # Upload to MySQL
    df.to_sql(
        name=table_name,
        con=engine,
        if_exists="replace",
        index=False
    )
    
    print(f"{file_name} uploaded successfully --> {table_name}")

print("All CSV files uploaded successfully.")
# Out:
# Database 'nova_bridge' is ready.
# interaction_file.csv uploaded successfully --> interaction
# All CSV files uploaded successfully.
